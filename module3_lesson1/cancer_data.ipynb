# %%
#Importing Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Dataset into Dataframe
df = pd.read_csv('cancer_data.csv')
#Check
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99           NaN          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ## DATA CLEANING
#
# >Check properly labelling of columns\
# >Check the columns data type\
# >Check for missing values,work on it by either to drop them or fill them up\
# >Check for rows with duplicates and drop them\
# >Check for the structure of the data set\

# %%
#check properly labelling of columns
df.columns #Columns are properly labeled i.e no missing value inbetween
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_SE', 'texture_SE', 'perimeter_SE', 'area_SE', 'smoothness_SE',
#        'compactness_SE', 'concavity_SE', 'concave_points_SE', 'symmetry_SE',
#        'fractal_dimension_SE', 'radius_max', 'texture_max', 'perimeter_max',
#        'area_max', 'smoothness_max', 'compactness_max', 'concavity_max',
#        'concave_points_max', 'symmetry_max', 'fractal_dimension_max'],
#       dtype='object')

# %%
#check the columns data type
df.dtypes# Columns are integer,object and float datatypes but mostly Float datatype
# Out:
# id                          int64
# diagnosis                  object
# radius_mean               float64
# texture_mean              float64
# perimeter_mean            float64
# area_mean                 float64
# smoothness_mean           float64
# compactness_mean          float64
# concavity_mean            float64
# concave_points_mean       float64
# symmetry_mean             float64
# fractal_dimension_mean    float64
# radius_SE                 float64
# texture_SE                float64
# perimeter_SE              float64
# area_SE                   float64
# smoothness_SE             float64
# compactness_SE            float64
# concavity_SE              float64
# concave_points_SE         float64
# symmetry_SE               float64
# fractal_dimension_SE      float64
# radius_max                float64
# texture_max               float64
# perimeter_max             float64
# area_max                  float64
# smoothness_max            float64
# ...

# %%
#check for missing values,work on it by either to drop them or fill them up
df.isna().sum()# there are missing values
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean              21
# perimeter_mean             0
# area_mean                  0
# smoothness_mean           48
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean             65
# fractal_dimension_mean     0
# radius_SE                  0
# texture_SE                21
# perimeter_SE               0
# area_SE                    0
# smoothness_SE             48
# compactness_SE             0
# concavity_SE               0
# concave_points_SE          0
# symmetry_SE               65
# fractal_dimension_SE       0
# radius_max                 0
# texture_max               21
# perimeter_max              0
# area_max                   0
# smoothness_max            48
# compactness_max            0
# concavity_max              0
# concave_points_max         0
# symmetry_max              65
# fractal_dimension_max      0
# ...

# %%
#Working on the missing values Using fillna to fill up empty spaces in the columns
#columns with the missinng values are float datatype filling them up with the average(mean)
# Fill up empty spaces  for 'texture_mean' column using the mean
a = df['texture_mean'].mean()
df['texture_mean'].fillna(a, inplace=True)

# Fill up empty spaces  for 'smoothness_mean' column using the mean
b = df['smoothness_mean'].mean()
df['smoothness_mean'].fillna(b, inplace=True)

# Fill up empty spaces  for 'symmetry_mean' column using the mean
c = df['symmetry_mean'].mean()
df['symmetry_mean'].fillna(c, inplace=True)

# Fill up empty spaces  for 'texture_SE' column using the mean
d = df['texture_SE'].mean()
df['texture_SE'].fillna(d, inplace=True)

# Fill up empty spaces for 'smoothness_SE' column using the mean
e = df['smoothness_SE'].mean()
df['smoothness_SE'].fillna(e, inplace=True)

# Fill up empty spaces  for 'symmetry_SE' column using the mean
f = df['symmetry_SE'].mean()
df['symmetry_SE'].fillna(f, inplace=True)

# Fill up empty spaces  for 'texture_max' column using the mean
g = df['texture_max'].mean()
df['texture_max'].fillna(g, inplace=True)

# Fill up empty spaces  for 'smoothness_max' column using the mean
h = df['smoothness_max'].mean()
df['smoothness_max'].fillna(h, inplace=True)

# Fill up empty spaces  for 'symmetry_max' column using the mean
i = df['symmetry_max'].mean()
df['symmetry_max'].fillna(i, inplace=True)

# %%
#Check for missing values again
df.isna().sum()
# Out:
# id                        0
# diagnosis                 0
# radius_mean               0
# texture_mean              0
# perimeter_mean            0
# area_mean                 0
# smoothness_mean           0
# compactness_mean          0
# concavity_mean            0
# concave_points_mean       0
# symmetry_mean             0
# fractal_dimension_mean    0
# radius_SE                 0
# texture_SE                0
# perimeter_SE              0
# area_SE                   0
# smoothness_SE             0
# compactness_SE            0
# concavity_SE              0
# concave_points_SE         0
# symmetry_SE               0
# fractal_dimension_SE      0
# radius_max                0
# texture_max               0
# perimeter_max             0
# area_max                  0
# smoothness_max            0
# compactness_max           0
# concavity_max             0
# concave_points_max        0
# symmetry_max              0
# fractal_dimension_max     0
# dtype: int64

# %%
#check for rows with duplicates
df[df.duplicated()]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 202    852552         M        16.65         21.38          110.00      904.6
# 325  89511502         B        12.67         17.30           81.25      489.9
# 345    898677         B        10.26         14.71           66.20      321.6
# 489   9113846         B        12.27         29.97           77.42      465.4
# 558    925277         B        14.59         22.68           96.39      657.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 202          0.11210           0.14570         0.15250              0.09170
# 325          0.10280           0.07664         0.03193              0.02107
# 345          0.09882           0.09159         0.03581              0.02037
# 489          0.07699           0.03398         0.00000              0.00000
# 558          0.08473           0.13300         0.10290              0.03736
#
# ...

# %%
#Drop Duplicates
df.drop_duplicates(inplace= True)

# %%
#Save clean dataframe
cleaned_df = df
cleaned_df.to_csv("Final_df.csv", index=False)

# %%
cleaned_df = pd.read_csv("Final_df.csv")
cleaned_df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99     19.293431          122.80     1001.0
# 1    842517         M        20.57     17.770000          132.90     1326.0
# 2  84300903         M        19.69     21.250000          130.00     1203.0
# 3  84348301         M        11.42     20.380000           77.58      386.1
# 4  84358402         M        20.29     14.340000          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0         0.118400           0.27760          0.3001              0.14710
# 1         0.084740           0.07864          0.0869              0.07017
# 2         0.109600           0.15990          0.1974              0.12790
# 3         0.096087           0.28390          0.2414              0.10520
# 4         0.100300           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS
# Get the Required Statistics for more understanding and insights of the Dataset

# %%
#To Get the shape
cleaned_df.shape
# Out:
# (564, 32)

# %%
#The Statistics of the dataframe
cleaned_df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.640000e+02   564.000000    564.000000      564.000000   564.000000
# mean   3.060557e+07    14.120335     19.276458       91.927784   654.047163
# std    1.255492e+08     3.514862      4.232968       24.221072   350.428965
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.690778e+05    11.697500     16.292500       75.135000   420.175000
# 50%    9.060010e+05    13.375000     18.905000       86.415000   551.400000
# 75%    8.873089e+06    15.797500     21.680000      103.925000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       564.000000        564.000000      564.000000           564.000000
# mean          0.096096          0.104610        0.088832             0.048967
# ...

# %%
#Correlation Statistics of the Dataframe
cleaned_df.corr()
# Out:
#                               id  radius_mean  texture_mean  perimeter_mean  \
# id                      1.000000     0.075607      0.102670        0.074114
# radius_mean             0.075607     1.000000      0.331186        0.997860
# texture_mean            0.102670     0.331186      1.000000        0.337239
# perimeter_mean          0.074114     0.997860      0.337239        1.000000
# area_mean               0.098309     0.987259      0.327695        0.986278
# smoothness_mean        -0.011705     0.164835     -0.031267        0.199778
# compactness_mean       -0.001029     0.503133      0.248914        0.554102
# concavity_mean          0.050553     0.673538      0.310958        0.712921
# concave_points_mean     0.044276     0.821903      0.300357        0.850334
# symmetry_mean          -0.024495     0.143403      0.059612        0.177461
# fractal_dimension_mean -0.053689    -0.312421     -0.070453       -0.262366
# ...

# %% [markdown]
# ## Using some colors that represents different kinds of cancer(yellow,orange,red)

# %%
#Plot and customize a correlations heatmap for cleaned_df.
corr=cleaned_df.corr()
# use numpy function to mask the data to create a matrix of booleans
ones = np.ones_like(corr, dtype='bool') # by default returns ones for all the data

# use another numpy function to get just the upper triangle of the boolean array
mask = np.triu(ones)

# adjust mask and correlations 
mask = mask[1:, :-1]
corr = corr.iloc[1:,:-1].copy()

# generate customized heatmap of correlations
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(corr, mask=mask, annot=True,fmt=".1f",cmap='YlOrRd', linewidths=.10, cbar_kws={'shrink':.99})
ax.xaxis.tick_bottom()
plt.title("Correlations heatmap of Cancer Data \n".upper(), fontdict={'fontsize': 25}, loc='center')
plt.show()

# %% [markdown]
# # Insights Using Visualisation

# %% [markdown]
# ## Understanding the distribution of the columns (_mean) values

# %%
plt.figure(figsize=(15,10)) 

plt.subplot(2,2,1)
sns.kdeplot(cleaned_df["radius_mean"], color='yellow'); 
plt.title('Distribution of radius_mean(Cancer data)'.upper())

plt.subplot(2,2,2)
sns.kdeplot(cleaned_df["texture_mean"], color='orange');
plt.title('Distribution of texture_mean(Cancer data)'.upper())

plt.subplot(2,2,3)
sns.kdeplot(cleaned_df["perimeter_mean"], color='red' );
plt.title('Distribution of perimeter_mean(Cancer data)'.upper())


plt.subplot(2,2,4)
sns.kdeplot(cleaned_df["area_mean"], color='brown');
plt.title('Distribution of area_mean(Cancer data)'.upper())

plt.subplots_adjust(wspace=0.5, hspace=0.5, bottom=0.1, top=0.9)
plt.show()

# %% [markdown]
# radius_mean is more distributed between 10 and 15 and less around 20\
# texture_mean is evenly distributed between 15 to 25\
# perimeter_mean is more distributed around 70 to 100 and less at 125\
# area_mean is very distributed at 500,less at 1000 and barely at 1500

# %% [markdown]
# # Insights on the the Relationship between Columns with commom values(_mean),(_SE),(_max) or different Specific Values

# %%
plt.figure(figsize=(15,10)) 
#Understanding the correlation of columns with the mean values
plt.subplot(2,2,1)
sns.regplot(x = cleaned_df["radius_mean"], y =cleaned_df["area_mean"], color='yellow' );
plt.title('Correlation between radius_mean \n and area_mean (Cancer data)'.upper())

#Understanding the Correlation of columns with the SE values 
plt.subplot(2,2,2)
sns.regplot(x = cleaned_df["smoothness_SE"], y =cleaned_df["symmetry_SE"], color='orange' );
plt.title('Correlation between smoothness_SE \n and symmetry_SE (cancer Data)'.upper())

#Understanding the Correlation of columns with the different specific values
plt.subplot(2,2,3)
sns.regplot(x = cleaned_df["radius_max"], y =cleaned_df["fractal_dimension_SE"], color='red' );
plt.title('Correlation between radius_max \n and fractal_dimension_se(cancer Data)'.upper())

#Understanding the Correlation of columns with the different specific values
plt.subplot(2,2,4)
sns.regplot(x = cleaned_df["smoothness_SE"], y =cleaned_df["area_mean"] , color='brown');
plt.title('Correlation between smoothness_se \n and area_mean (cancer Data)'.upper())

plt.subplots_adjust(wspace=0.5, hspace=0.5, bottom=0.1, top=0.9)
plt.show()

# %% [markdown]
# Columns with values in common(_mean),(_SE),(_max)are positively correlated with each other they differ between high or low\
# Columns with different specific values are negatively correlated or no correlation with each other\

# %% [markdown]
# ## Does the smoothness have anything to with Texture during diagnosis in the Cancer data?

# %%
minimum_spread =  cleaned_df.query("smoothness_mean < 15")

minimum_spread.groupby("diagnosis")["texture_mean"].mean().plot(kind = "bar",color='Red');

# %% [markdown]
# Diagnosis M(Malignant) has less smoothness than Diagnosis B(Benign) thereby affecting the texture
